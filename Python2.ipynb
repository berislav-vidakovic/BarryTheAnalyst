# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\User\Documents\BLOG\Python\population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  Area (km²)  Density (per km²)  Growth Rate  \
# 0         41128771.0    652230.0            63.0587       1.0257
# 1          2842321.0     28748.0            98.8702       0.9957
# ...

# %%
df[df['Rank'] <= 4]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  Area (km²)  Density (per km²)  Growth Rate  \
# 41      1.425887e+09   9706961.0           146.8933       1.0000
# 92      1.417173e+09   3287590.0           431.0675       1.0068
# 93      2.755013e+08   1904569.0           144.6529       1.0064
# 221     3.382899e+08   9372610.0            36.0935       1.0038
#
#      World Population Percentage
# 41                         17.88
# 92                         17.77
# 93                          3.45
# 221                         4.24

# %%
specific_cnt=['India', 'Indonesia']

# %%
df[df['Country'].isin(specific_cnt)]
# Out:
#     Rank CCA3    Country    Capital Continent  2022 Population  Area (km²)  \
# 92     2  IND      India  New Delhi      Asia     1.417173e+09   3287590.0
# 93     4  IDN  Indonesia    Jakarta      Asia     2.755013e+08   1904569.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 92           431.0675       1.0068                        17.77
# 93           144.6529       1.0064                         3.45

# %%
df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  Area (km²)  Density (per km²)  Growth Rate  \
# 219        9441129.0     83600.0           112.9322       1.0081
# 220       67508936.0    242900.0           277.9289       1.0034
# 221      338289857.0   9372610.0            36.0935       1.0038
# 222          99465.0       347.0           286.6427       0.9937
#
#      World Population Percentage
# 219                         0.12
# 220                         0.85
# 221                         4.24
# 222                         0.00

# %%
df2=df.set_index('Country')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
#                    Area (km²)  Density (per km²)  Growth Rate  \
# ...

# %%
df2.filter(items=['Germany'], axis=0)
# Out:
#          Rank CCA3 Capital Continent  2022 Population  Area (km²)  \
# Country
# Germany    19  DEU  Berlin    Europe       83369843.0    357114.0
#
#          Density (per km²)  Growth Rate  World Population Percentage
# Country
# Germany           233.4544       0.9995                         1.05

# %%
df2.filter(like='United', axis=0)
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country
# United Arab Emirates            97  ARE         Abu Dhabi           Asia
# United Kingdom                  21  GBR            London         Europe
# United States                    3  USA  Washington, D.C.  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  Area (km²)  Density (per km²)  \
# Country
# United Arab Emirates                9441129.0     83600.0           112.9322
# United Kingdom                     67508936.0    242900.0           277.9289
# United States                     338289857.0   9372610.0            36.0935
# United States Virgin Islands          99465.0       347.0           286.6427
#
#                               Growth Rate  World Population Percentage
# Country
# United Arab Emirates               1.0081                         0.12
# ...

# %%
df2.loc['Croatia']
# Out:
# Rank                                 130
# CCA3                                 HRV
# Capital                           Zagreb
# Continent                         Europe
# 2022 Population                4030358.0
# Area (km²)                       56594.0
# Density (per km²)                71.2153
# Growth Rate                       0.9927
# World Population Percentage         0.05
# Name: Croatia, dtype: object

# %%
df2.iloc[96]
# Out:
# Rank                                 125
# CCA3                                 IRL
# Capital                           Dublin
# Continent                         Europe
# 2022 Population                5023109.0
# Area (km²)                       70273.0
# Density (per km²)                71.4799
# Growth Rate                       1.0073
# World Population Percentage         0.06
# Name: Ireland, dtype: object

# %%
df3=df[df['Rank'] < 10]
df3
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  Area (km²)  Density (per km²)  Growth Rate  \
# 16      1.711864e+08    147570.0          1160.0350       1.0108
# 27      2.153135e+08   8515767.0            25.2841       1.0046
# 41      1.425887e+09   9706961.0           146.8933       1.0000
# 92      1.417173e+09   3287590.0           431.0675       1.0068
# ...

# %%
df3.sort_values(by='Rank')
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
#
#      2022 Population  Area (km²)  Density (per km²)  Growth Rate  \
# 41      1.425887e+09   9706961.0           146.8933       1.0000
# 92      1.417173e+09   3287590.0           431.0675       1.0068
# 221     3.382899e+08   9372610.0            36.0935       1.0038
# 93      2.755013e+08   1904569.0           144.6529       1.0064
# ...

# %%
df3.sort_values(by=['Continent','Country'],ascending=[False,True])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 221     3  USA  United States  Washington, D.C.  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  Area (km²)  Density (per km²)  Growth Rate  \
# 27      2.153135e+08   8515767.0            25.2841       1.0046
# 221     3.382899e+08   9372610.0            36.0935       1.0038
# 171     1.447133e+08  17098242.0             8.4636       0.9973
# 16      1.711864e+08    147570.0          1160.0350       1.0108
# ...
