# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\User\Documents\BLOG\Python\population.csv",index_col="Country")

# %%
df.reset_index(inplace=True)

# %%
df.set_index('Country',inplace=True)

# %%
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
#                    Area (km²)  Density (per km²)  Growth Rate  \
# ...

# %%
df2=df[df['Rank']<=10]

# %%
df2.reset_index(inplace=True)

# %%
df2.set_index(['Continent','Country'],inplace=True)

# %%
df2.sort_index(ascending=[False,True])
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent     Country
# South America Brazil            7  BRA          Brasilia     2.153135e+08
# North America Mexico           10  MEX       Mexico City     1.275041e+08
#               United States     3  USA  Washington, D.C.     3.382899e+08
# Europe        Russia            9  RUS            Moscow     1.447133e+08
# Asia          Bangladesh        8  BGD             Dhaka     1.711864e+08
#               China             1  CHN           Beijing     1.425887e+09
#               India             2  IND         New Delhi     1.417173e+09
#               Indonesia         4  IDN           Jakarta     2.755013e+08
#               Pakistan          5  PAK         Islamabad     2.358249e+08
# Africa        Nigeria           6  NGA             Abuja     2.185412e+08
#
#                              Area (km²)  Density (per km²)  Growth Rate  \
# Continent     Country
# ...
